# %% [markdown]
# # TSP problem using CE Method

# %% [markdown]
# Creer un example ou la convergence rapide vers les 0 pose probleme et le resoudre
# Supperposer les solutions Bayesienne et cross entropy

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import permutations

# %%
class TSP(object):
    """Classe permettant de résoudre un problème TSP, deux versions sont disponibles :
        -la version originale proposée par les auteurs de la méthode (avec un smooth update possible)
        -une version prenant une approche bayésienne
    
    Attributs à entrer par l'utilisateur:
        c: matrice de poids pour les trajets entre les villes.
        methode: au choix entre "CE" pour la 1ere version et "Bayes" pour la 2nd
        k: nombre de simulations pour chaque update de la forme k*(nombre villes)^2 (int)
        perc: percentile fixé dans l'algo (int entre 1 et 100) 
        seed: graine pour fixer l'aléatoire (int)
        stop: critère d'arrêt (on s'arrète quand les d derniers quantiles sont les mêmes)
        alpha: "smoothing" parameter (1ere version only)
        
    Attributs:
        n: nombre de villes
        N: nombre de simulations pour chaque update
        p: matrice de transition entre les villes (pij proba de passer de la ville i à la ville j),
           initialisée par des Dirichlet uniformes
        p_old: version de p de l'update précédent (1ere version only)
        r: matrice des paramètres de Dirichlet (chaque ligne correspond à une Dirichlet), 
           initialisée avec alpha=1 (2eme version only)
        r_old: version de r de l'update précédent (2eme version only)
        
        
    Méthodes: (Voir aide spécifique à chaque méthode pour plus de détails)
    """
    
    def __init__(self, c, methode="CE", k=10, perc=1, alpha=0.9, seed=None, stop=5, show_p=5,show_q=10):
        """Constructeur de la classe TSPBayes"""
        
        if methode not in ["CE","Bayes"]:
            print("Mauvaise méthode, méthodes disponibles : Bayes, CE")
            sys.exit(1)
            
        self.c = c
        self.methode = methode
        self.n = c.shape[0]
        self.N = k * self.n**2
        self.perc = perc
        self.seed = seed
        self.stop = stop
        self.solution = None
        self.show_p = show_p
        self.show_q = show_q
        if self.methode=="CE":
            self.alpha = alpha
            self.p=(np.ones((self.n,self.n))-np.eye(self.n))*(1/float(self.n-1))
            self.p_old = self.p
            
        if self.methode=="Bayes":
            self.p = self.p_init()
            self.r = np.ones((self.n,self.n)) - np.eye(self.n)
            self.r_old = self.r

    def gen_dir(self,alpha):
        '''Simule 1 observation de loi de Dirichlet. (2eme version only)
        Ne prend en compte que les paramètres positifs'''
        
        alpha = alpha[alpha>0]
        
        return np.random.dirichlet(alpha,1)
        

    def p_init(self):
        """Initialise la matrice p avec des Dirichlet uniformes (2eme version only)
        Chaque ligne est simulée selon une Dirichlet(1,...,1) 
        """
        
        p = np.zeros((self.n,self.n))
        
        for i in range(self.n):
            
            row = self.gen_dir(np.tile(1,self.n-1))
            #On insert des 0 car la matrice p ne doit contenir que des 0 sur sa diagonale
            row = np.insert(row,i,0)
            p[i,:] = row

        return p
        
    def generate_tours(self):
        """Génère N tours selon les probabilités de transition de p
        Retourne une matrice de taille N*n où chaque ligne est un tour"""
    
        #première ville toujours 0 (mieux de prendre 0 que 1 pour les indices des matrices)
        #Fixer la ville de départ se fait sans perte de généralité
        tours = np.zeros((self.N,(self.n+1)),dtype=int)

        for obs in range(self.N):
            
            p = self.p.copy()
            
            for step in range(1,(self.n)):
                
                #colonne dernière ville du tour mise à 0 pour qu'on n'y repasse pas
                p[:,tours[obs,(step-1)]] = 0 
                
                with np.errstate(invalid='ignore', divide='ignore'): 
                    p = (np.divide(p.T,p.sum(axis=1))).T #renormalise pour que les colonnes somment à 1
                
                #génère une multinomiale(1,p1,...,pn) pour trouver la prochaine ville
                tours[obs,step] = np.random.choice(np.arange(self.n),1, p=p[tours[obs,(step-1)],:])[0]
                
            tours[obs,-1] = 0 #retour à la ville 0 (départ)
            
        return tours
        
    def S(self,x):
        '''Calcule la performance du tour par rapport à la matrice de poids c
        Performance = somme des distances parcourues entre les villes'''
        
        score = 0
        for i in range(len(x)-1):
            score += self.c[x[i],x[i+1]] #cout d'aller d'une ville à une autre 

        return score
    
    def construct_mult(self,x,score,q):
        '''Construction des observations multinomiales à partir des tours, 
        de leur score et du quantile (2eme version only)'''
        
        m =  np.zeros_like(self.r)
    
        x = x[score<=q,:]
        
        for obs in range(x.shape[0]):
            
            for idx in range(x.shape[1]-1):
                i = x[obs,idx]
                j = x[obs,idx+1]
                m[i,j] += 1
   
        return m

    
    def update_Bayes(self,x,score,q):
        '''Update bayésien de la matrice p. (2eme version only)
        Calcul des nouveau coefficients des Dirichlet par la formule de Bayes 
        simulation de la nouvelle matrice p par ces lois Dirichlet'''
        
        r_temp = self.r.copy()
        self.r = self.construct_mult(x,score,q)
        self.r_old = r_temp
        
        self.r = self.r + self.r_old
        
        p = np.zeros((self.n,self.n))
        
        for i in range(self.n):
            
            u = self.gen_dir(self.r[i,:])
            u = np.insert(u,i,0)
            p[i,:] = u
            
        self.p = p
            
        return None
    
    def update_CE(self,x, score,q):
        '''Permet de faire l'update "smooth" des probas de transition pij (1ere version only)
        la methode "smooth" evite les problemes avec des 0 au mauvais endroits'''
        self.p_old = self.p.copy()
        p =  np.zeros_like(self.p)
        
        x = x[score<=q,:]
        
        for obs in range(x.shape[0]):
            
            for idx in range(x.shape[1]-1):
                i = x[obs,idx]
                j = x[obs,idx+1]
                p[i,j] += 1

        p = np.divide(p,float(x.shape[0]))
        
        self.p = self.alpha*p + (1-self.alpha)*self.p_old
             
        return None
    
    
    def show_prob(self):
        '''Affiche p sous forme de HeatMap'''
        
        plt.figure(figsize=(8,8))
        plt.matshow(self.p,fignum=1)
        plt.xlabel('j')
        plt.ylabel('i')
        plt.grid('off')
        plt.colorbar()
        plt.show()
    
 
    def CE_fit(self):
        
        if self.seed: 
         #fixe aléa
         np.random.seed(self.seed)
         
        #Critére d'arrêt : les 'stop' derniers quantiles calculés sont les mêmes, q_memory les stockent
        #q_memory = np.zeros(self.stop)
        q_memory = np.array([])
        
        epoch = 0
        best_score = np.infty
        
        print("Vous utilisez la méthode : {}".format(self.methode))
        
        while True:
            epoch += 1
            print("Epoch {}".format(epoch))
            
            #genere les "tours"
            x = self.generate_tours().astype(np.int)
            
            #calcul du score pour chaque tour
            score = np.apply_along_axis(lambda x: self.S(x),1,x)
            
            #quantile
            q = np.percentile(score,self.perc)
            
            best = np.min(score)
            if best < best_score: 
                best_score = best
                self.solution = x[np.argmin(score),:]
                
            print("Quantile : {}, Meilleur score : {}".format(q,best))
            
            #on update nos quantiles pour le critère d'arrêt dans la memory
            #q_memory[:-1] = q_memory[1:]
            #q_memory[-1] = q
            q_memory = np.append(q_memory,[q])
                        
            if epoch%self.show_p==0: 
                self.show_prob()
                
            if epoch%self.show_q==0: 
                plt.plot(q_memory)
                plt.show()
            
            if self.methode=="CE":
                #smooth update
                self.update_CE(x,score,q)
                
            if self.methode=="Bayes":
                self.update_Bayes(x,score,q)
                
            #si les 5 derniers quantiles sont les mêmes ont arrête
            if len(q_memory)>5:
                if len(set(q_memory[-self.stop:]))==1 : break  
        
        #Affichage finale
        self.show_prob()
        plt.plot(q_memory)
        plt.show()
        print("final epoch {}, dernier quantile : {}".format(epoch,q))
        print("Meilleur score {}, solution : {}".format(best_score,self.solution))
                
        return

# %% [markdown]
# # Applications

# %%
def get_distance_from_cartesian(arr):
    '''Fonction permettant de calculer la matrice des distances à partir d'une liste de coordonnées cartésiennes'''
    
    n = arr.shape[0]
    c = np.zeros((n,n))
    
    for i in range(n):
        for j in range(i,n):
            c[i,j] = np.sqrt((arr[i,0]-arr[j,0])**2 + (arr[i,1]-arr[j,1])**2)
            
    c += c.T
    
    return c

# %%
from math import sin, cos, sqrt, atan2, radians

def get_distance_from_geographic(arr):
    '''Fonction permettant de calculer la matrice des distances à partir d'une liste
    de latitudes et longitudes'''
    
    # approximate radius of earth in km
    R = 6373.0
    n = arr.shape[0]
    distance_mat = np.zeros((n,n))
    
    for i in range(n):
        for j in range(i,n):
        
            lat1 = radians(arr[i,0])
            lon1 = radians(arr[i,1])
            lat2 = radians(arr[j,0])
            lon2 = radians(arr[j,1])
            
            dlon = lon2 - lon1
            dlat = lat2 - lat1

            a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
            c = 2 * atan2(sqrt(a), sqrt(1 - a))

            distance = R * c
            distance_mat[i,j] = distance
            
    distance_mat += distance_mat.T
    
    return distance_mat

# %%
def best_score(TSP):
    '''Calcul la vraie solution d'un probleme TSP
    La taille de la boucle est n! donc à ne pas tester sur plus d'une dizaine de villes'''
    
    mini = np.infty
    for tours in permutations(range(1,TSP.n)):
        s = TSP.S((0,) + tours + (0,))
        if s< mini:
            mini = s
    return mini

# %%
def CE_solution(c,method="CE",k=10,perc=1):
    '''Fit la classe TSP sur un matrice de distances c'''
    
    tsp = TSP(c,k=k,perc=perc,methode=method)
    tsp.CE_fit()
    return tsp

# %%
def plot_solution_cartesian(tsp,d):
    '''tsp : objet TSP fitté, 
    d :  matrice contenant les coordonnées cartésiennes'''

    #Ensemble de points
    print("Ensemble des villes dans le plan")
    plt.plot(d[:,0],d[:,1],".")
    plt.axis("off")
    plt.show()
    
    #Solution
    print("Trajet optimal")
    permut = tsp.solution
    plt.plot(my_data[permut,0],my_data[permut,1])
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Examples à moins de 20 villes

# %%
my_data = np.genfromtxt('tiny.csv', delimiter=',')
my_data
# Out:
# array([[-1.0856306 , -0.67888615],
#        [ 0.99734545, -0.09470897],
#        [ 0.2829785 ,  1.49138963],
#        [-1.50629471, -0.638902  ],
#        [-0.57860025, -0.44398196],
#        [ 1.65143654, -0.43435128],
#        [-2.42667924,  2.20593008],
#        [-0.42891263,  2.18678609],
#        [ 1.26593626,  1.0040539 ],
#        [-0.8667404 ,  0.3861864 ]])

# %%
c = get_distance(my_data)
c
# Out:
# array([[0.        , 2.16334283, 2.56577236, 0.42256009, 0.55880207,
#         2.74796904, 3.1812853 , 2.93995848, 2.89173891, 1.08733273],
#        [2.16334283, 0.        , 1.73954847, 2.56210072, 1.61418601,
#         0.73701564, 4.12515274, 2.69061922, 1.13111488, 1.92511724],
#        [2.56577236, 1.73954847, 0.        , 2.78202103, 2.11848557,
#         2.36244691, 2.80228713, 0.99517095, 1.09713357, 1.5947814 ],
#        [0.42256009, 2.56210072, 2.78202103, 0.        , 0.94795086,
#         3.16434948, 2.99001292, 3.02411397, 3.22250968, 1.20823671],
#        [0.55880207, 1.61418601, 2.11848557, 0.94795086, 0.        ,
#         2.23005758, 3.23070113, 2.63502313, 2.34502085, 0.87875153],
#        [2.74796904, 0.73701564, 2.36244691, 3.16434948, 2.23005758,
#         0.        , 4.85820069, 3.34637322, 1.48916752, 2.6484896 ],
#        [3.1812853 , 4.12515274, 2.80228713, 2.99001292, 3.23070113,
#         4.85820069, 0.        , 1.99785834, 3.8832867 , 2.39684715],
#        [2.93995848, 2.69061922, 0.99517095, 3.02411397, 2.63502313,
#         3.34637322, 1.99785834, 0.        , 2.06672886, 1.85306568],
#        [2.89173891, 1.13111488, 1.09713357, 3.22250968, 2.34502085,
#         1.48916752, 3.8832867 , 2.06672886, 0.        , 2.22037609],
#        [1.08733273, 1.92511724, 1.5947814 , 1.20823671, 0.87875153,
#         2.6484896 , 2.39684715, 1.85306568, 2.22037609, 0.        ]])

# %%
# %%time
tsp = CE_solution(c,method="Bayes")
# Out:
# Vous utilisez la méthode : Bayes
# Epoch 1
# Quantile : 17.5715538923, Meilleur score : 15.1327142536
# Epoch 2
# Quantile : 14.6410760362, Meilleur score : 13.0430417804
# Epoch 3
# Quantile : 13.8791845771, Meilleur score : 12.7747969708
# Epoch 4
# Quantile : 12.7747969708, Meilleur score : 12.5169780398
# Epoch 5
# Quantile : 12.5169780398, Meilleur score : 12.5169780398
# Epoch 6
# Quantile : 12.5169780398, Meilleur score : 12.5169780398
# Epoch 7
# Quantile : 12.5169780398, Meilleur score : 12.5169780398
# Epoch 8
# Quantile : 12.5169780398, Meilleur score : 12.5169780398
# Epoch 9
# Quantile : 12.5169780398, Meilleur score : 12.5169780398
# final epoch 9, dernier quantile : 12.5169780398
# Meilleur score 12.5169780398, solution : [0 4 1 5 8 2 7 6 9 3 0]
# CPU times: user 5.43 s, sys: 119 ms, total: 5.55 s
# Wall time: 5.11 s

# %%
print(tsp.solution)
# Out:
# [0 4 1 5 8 2 7 6 9 3 0]

# %% [markdown]
# Visualisation de la solution

# %%
plot_solution(tsp,my_data)
# Out:
# Ensemble des villes dans le plan
# Trajet optimal

# %% [markdown]
# ## Examples à moins de 30 villes

# %%
my_data = np.genfromtxt('small.csv', delimiter=',')

# %%
c = get_distance(my_data)
c.shape
# Out:
# (30, 30)

# %%
# %%time
tsp = CE_solution(c,method="CE")
# Out:
# Vous utilisez la méthode : CE
# Epoch 1
# Quantile : 224.722006221, Meilleur score : 166.200409262
# Epoch 2
# Quantile : 157.740605259, Meilleur score : 106.423013882
# Epoch 3
# Quantile : 114.770701974, Meilleur score : 90.8729174123
# Epoch 4
# Quantile : 93.8894590928, Meilleur score : 79.7158769614
# Epoch 5
# Quantile : 84.1933624174, Meilleur score : 71.9405699546
# Epoch 6
# Quantile : 78.251906305, Meilleur score : 70.9173048917
# Epoch 7
# Quantile : 74.8883919311, Meilleur score : 66.3631051453
# Epoch 8
# Quantile : 72.4084292499, Meilleur score : 65.899264206
# Epoch 9
# Quantile : 70.4491614929, Meilleur score : 65.7081540394
# Epoch 10
# Quantile : 68.348440634, Meilleur score : 64.467345934
# Epoch 11
# Quantile : 66.8126865298, Meilleur score : 63.6714268128
# Epoch 12
# Quantile : 65.2061217848, Meilleur score : 62.5604245797
# Epoch 13
# Quantile : 63.5483578756, Meilleur score : 61.6442338057
# Epoch 14
# Quantile : 62.1714915952, Meilleur score : 60.8422718021
# Epoch 15
# Quantile : 60.8422718021, Meilleur score : 60.4051551351
# Epoch 16
# Quantile : 60.4051551351, Meilleur score : 60.1773663655
# Epoch 17
# Quantile : 60.4051551351, Meilleur score : 60.4051551351
# Epoch 18
# Quantile : 60.4051551351, Meilleur score : 60.4051551351
# Epoch 19
# Quantile : 60.4051551351, Meilleur score : 60.4051551351
# Epoch 20
# Quantile : 60.4051551351, Meilleur score : 60.4051551351
# final epoch 20, dernier quantile : 60.4051551351
# Meilleur score 60.1773663655, solution : [ 0 19  6  9 29 22 27 11 14  2 18  5 23 26  1 10 24  8 17 21 16 12 15 25
#   7  3 28 20  4 13  0]
# CPU times: user 5min 14s, sys: 2.42 s, total: 5min 17s
# Wall time: 5min 23s

# %%
print(tsp.solution)
# Out:
# [ 0 19  6  9 29 22 27 11 14  2 18  5 23 26  1 10 24  8 17 21 16 12 15 25
#   7  3 28 20  4 13  0]

# %%
plot_solution(tsp,my_data)
# Out:
# Ensemble des villes dans le plan
# Trajet optimal

# %% [markdown]
# ## Tour du monde

# %%
df = pd.read_csv("worldcities.csv")

# %%
df = df[df.capital=="primary"]
df = df[~(df.population.isna())]

# %%
df.head()
# Out:
#              city    city_ascii      lat      lng       country iso2 iso3  \
# 39          Sanaa         Sanaa  15.3547  44.2066         Yemen   YE  YEM
# 135      Pretoria      Pretoria -25.7069  28.2294  South Africa   ZA  ZAF
# 136  Bloemfontein  Bloemfontein -29.1200  26.2299  South Africa   ZA  ZAF
# 137     Cape Town     Cape Town -33.9200  18.4350  South Africa   ZA  ZAF
# 140        Lusaka        Lusaka -15.4166  28.2833        Zambia   ZM  ZMB
#
#             admin_name  capital  population          id
# 39   Amānat al ‘Āşimah  primary   2008000.0  1887750814
# 135            Gauteng  primary   1338000.0  1710176249
# 136         Free State  primary    463064.0  1710495933
# 137       Western Cape  primary   3215000.0  1710680650
# 140             Lusaka  primary   1328000.0  1894157390

# %%
#On ne sélectionne que les p plus grandes villes en terme de population
p = 50
df = df.sort_values("population")[-p:]
df.shape
# Out:
# (50, 11)

# %%
#On construit la matrice des distances
my_data = df[["lat","lng"]].values
c = get_distance_from_geographic(my_data)
c.shape
# Out:
# (50, 50)

# %% [markdown]
# ### Smooth Update

# %%
# %%time
tsp_Smooth = CE_solution(c,met235hod="CE")
# Out:
# Vous utilisez la méthode : CE
# Epoch 1
# Quantile : 327702.092455, Meilleur score : 286337.749975
# Epoch 2
# Quantile : 271538.769668, Meilleur score : 227216.365703
# Epoch 3
# Quantile : 227955.969884, Meilleur score : 180743.770095
# Epoch 4
# Quantile : 194064.879433, Meilleur score : 161826.285746
# Epoch 5
# Quantile : 170753.296891, Meilleur score : 146862.939527
# Epoch 6
# Quantile : 153582.433953, Meilleur score : 129066.230571
# Epoch 7
# Quantile : 142576.42331, Meilleur score : 119923.143893
# Epoch 8
# Quantile : 134537.604305, Meilleur score : 110817.174717
# Epoch 9
# Quantile : 128705.471528, Meilleur score : 108508.357349
# Epoch 10
# Quantile : 123361.462047, Meilleur score : 110306.713259
# Epoch 11
# Quantile : 118756.038428, Meilleur score : 100925.765997
# Epoch 12
# Quantile : 113674.000816, Meilleur score : 99039.2555056
# Epoch 13
# Quantile : 108526.47654, Meilleur score : 98885.0133279
# Epoch 14
# Quantile : 105024.749352, Meilleur score : 94407.6431074
# Epoch 15
# Quantile : 101821.603206, Meilleur score : 94772.2007783
# Epoch 16
# Quantile : 99655.154803, Meilleur score : 92076.4479788
# Epoch 17
# Quantile : 98011.9989782, Meilleur score : 89833.3893623
# Epoch 18
# Quantile : 96232.4537588, Meilleur score : 88760.8303889
# Epoch 19
# Quantile : 94829.6900735, Meilleur score : 87691.356263
# Epoch 20
# Quantile : 93527.8426924, Meilleur score : 84926.1788669
# Epoch 21
# Quantile : 91696.4005699, Meilleur score : 88021.6808465
# Epoch 22
# Quantile : 89984.4103622, Meilleur score : 84896.2945417
# Epoch 23
# Quantile : 88880.9585145, Meilleur score : 83963.9866636
# Epoch 24
# Quantile : 87679.5584484, Meilleur score : 83391.0197566
# Epoch 25
# Quantile : 86510.2879504, Meilleur score : 83391.0197566
# Epoch 26
# Quantile : 85853.1462953, Meilleur score : 83163.1111828
# Epoch 27
# Quantile : 85625.2377216, Meilleur score : 83163.1111828
# Epoch 28
# Quantile : 83163.1111828, Meilleur score : 83163.1111828
# Epoch 29
# Quantile : 83163.1111828, Meilleur score : 83163.1111828
# Epoch 30
# Quantile : 83163.1111828, Meilleur score : 83163.1111828
# Epoch 31
# Quantile : 83163.1111828, Meilleur score : 83163.1111828
# Epoch 32
# Quantile : 83163.1111828, Meilleur score : 83163.1111828
# final epoch 32, dernier quantile : 83163.1111828
# Meilleur score 83163.1111828, solution : [ 0 10 34 37 31 46 21  6  8 30 18  4  2 14 20  5 45 25 35 27 13  9 11 12
#  24 26 36 15 47 22 32 23 44 16 40 49 33 43 39 28  1 42  7 19  3 17 41 38
#  29 48  0]
# CPU times: user 38min 43s, sys: 7.94 s, total: 38min 51s
# Wall time: 39min 5s

# %%
print(tsp_Smooth.solution)
# Out:
# [ 0 10 34 37 31 46 21  6  8 30 18  4  2 14 20  5 45 25 35 27 13  9 11 12
#  24 26 36 15 47 22 32 23 44 16 40 49 33 43 39 28  1 42  7 19  3 17 41 38
#  29 48  0]

# %% [markdown]
# ### Bayesian

# %%
# %%time
tsp_Bayes = CE_solution(c,method="Bayes", perc = 0.1)
# Out:
# Vous utilisez la méthode : Bayes
# Epoch 1
# Quantile : 306040.011925, Meilleur score : 287543.785884
# Epoch 2
# Quantile : 277355.320453, Meilleur score : 254641.479463
# Epoch 3
# Quantile : 260385.688787, Meilleur score : 229715.892809
# Epoch 4
# Quantile : 250701.785889, Meilleur score : 218106.485555
# Epoch 5
# Quantile : 236008.668198, Meilleur score : 214308.742868
# Epoch 6
# Quantile : 230869.877678, Meilleur score : 198998.864144
# Epoch 7
# Quantile : 221201.193807, Meilleur score : 199239.15852
# Epoch 8
# Quantile : 218242.149689, Meilleur score : 196103.926704
# Epoch 9
# Quantile : 213183.469494, Meilleur score : 199123.670518
# Epoch 10
# Quantile : 208043.522641, Meilleur score : 191751.84444
# Epoch 11
# Quantile : 203813.968371, Meilleur score : 192715.092129
# Epoch 12
# Quantile : 199744.165857, Meilleur score : 183523.494677
# Epoch 13
# Quantile : 195313.260115, Meilleur score : 174928.575084
# Epoch 14
# Quantile : 195373.345917, Meilleur score : 177953.420409
# Epoch 15
# Quantile : 193621.436733, Meilleur score : 176563.388692
# Epoch 16
# Quantile : 186730.407267, Meilleur score : 171688.205416
# Epoch 17
# Quantile : 187140.561081, Meilleur score : 172266.679009
# Epoch 18
# Quantile : 186401.209339, Meilleur score : 168380.418241
# Epoch 19
# Quantile : 182732.157624, Meilleur score : 164465.096572
# Epoch 20
# Quantile : 180038.715325, Meilleur score : 154247.712533
# Epoch 21
# Quantile : 179643.116475, Meilleur score : 170498.818531
# Epoch 22
# Quantile : 177807.022812, Meilleur score : 160496.395989
# Epoch 23
# Quantile : 176313.336561, Meilleur score : 162006.160849
# Epoch 24
# Quantile : 175189.739263, Meilleur score : 159292.96551
# Epoch 25
# Quantile : 175282.030477, Meilleur score : 156092.906377
# Epoch 26
# Quantile : 170958.442948, Meilleur score : 153102.743942
# Epoch 27
# Quantile : 172308.967592, Meilleur score : 151058.06378
# Epoch 28
# Quantile : 169993.512374, Meilleur score : 151702.557743
# Epoch 29
# Quantile : 168626.468703, Meilleur score : 140863.715304
# Epoch 30
# Quantile : 167812.699278, Meilleur score : 149113.295349
# Epoch 31
# Quantile : 167439.195828, Meilleur score : 151642.812705
# Epoch 32
# Quantile : 165261.098339, Meilleur score : 146796.755059
# Epoch 33
# Quantile : 167672.486406, Meilleur score : 155491.396622
# Epoch 34
# Quantile : 165494.73504, Meilleur score : 147335.062503
# Epoch 35
# Quantile : 164442.747372, Meilleur score : 134139.1665
# Epoch 36
# Quantile : 162841.029531, Meilleur score : 138268.04278
# Epoch 37
# Quantile : 159241.1931, Meilleur score : 145203.852837
# Epoch 38
# Quantile : 160346.069598, Meilleur score : 145341.079295
# Epoch 39
# Quantile : 160943.761908, Meilleur score : 146805.198323
# Epoch 40
# Quantile : 158015.299736, Meilleur score : 147430.358562
# Epoch 41
# Quantile : 157748.006363, Meilleur score : 143921.202643
# Epoch 42
# Quantile : 158022.611361, Meilleur score : 144884.520026
# Epoch 43
# Quantile : 157747.599935, Meilleur score : 136183.625229
# Epoch 44
# Quantile : 156943.942325, Meilleur score : 144003.265038
# Epoch 45
# Quantile : 155862.030631, Meilleur score : 139516.693168
# Epoch 46
# Quantile : 156638.19036, Meilleur score : 138438.910757
# Epoch 47
# Quantile : 157129.240492, Meilleur score : 136564.710769
# Epoch 48
# Quantile : 154241.530763, Meilleur score : 146189.602457
# Epoch 49
# Quantile : 152302.780051, Meilleur score : 131150.157432
# Epoch 50
# Quantile : 153146.909938, Meilleur score : 141515.602445
# Epoch 51
# Quantile : 154528.510248, Meilleur score : 143313.971952
# Epoch 52
# Quantile : 153541.563275, Meilleur score : 138566.349824
# Epoch 53
# Quantile : 155273.004718, Meilleur score : 141531.646554
# Epoch 54
# Quantile : 150728.171506, Meilleur score : 136626.826186
# Epoch 55
# Quantile : 153753.052388, Meilleur score : 141731.237659
# Epoch 56
# Quantile : 151569.693688, Meilleur score : 139434.813192
# Epoch 57
# Quantile : 151298.261894, Meilleur score : 140483.167086
# Epoch 58
# Quantile : 151211.87399, Meilleur score : 140599.275912
# Epoch 59
# Quantile : 149384.64835, Meilleur score : 130937.716857
# Epoch 60
# Quantile : 149192.511151, Meilleur score : 137665.825098
# Epoch 61
# Quantile : 148562.138746, Meilleur score : 136969.578434
# Epoch 62
# Quantile : 149183.389712, Meilleur score : 134733.340189
# Epoch 63
# Quantile : 149436.689468, Meilleur score : 134651.947155
# Epoch 64
# Quantile : 148455.681319, Meilleur score : 134517.455921
# Epoch 65
# Quantile : 146802.712029, Meilleur score : 128161.879577
# Epoch 66
# Quantile : 148440.230696, Meilleur score : 134250.199043
# Epoch 67
# Quantile : 148736.173315, Meilleur score : 136133.214513
# Epoch 68
# Quantile : 146556.637064, Meilleur score : 127192.813593
# Epoch 69
# Quantile : 146207.151412, Meilleur score : 136577.906628
# Epoch 70
# Quantile : 144970.080672, Meilleur score : 127778.194862
# Epoch 71
# Quantile : 145396.80228, Meilleur score : 133333.047394
# Epoch 72
# Quantile : 144240.137597, Meilleur score : 133719.46228
# Epoch 73
# Quantile : 145112.1522, Meilleur score : 127770.349389
# Epoch 74
# Quantile : 145059.93298, Meilleur score : 133858.805662
# Epoch 75
# Quantile : 144095.166524, Meilleur score : 136768.089018
# Epoch 76
# Quantile : 145640.497408, Meilleur score : 130489.171608
# Epoch 77
# Quantile : 143163.709672, Meilleur score : 125763.922764
# Epoch 78
# Quantile : 143756.565599, Meilleur score : 133119.410431
# Epoch 79
# Quantile : 142957.464707, Meilleur score : 129622.239947
# Epoch 80
# Quantile : 143189.169521, Meilleur score : 131580.721562
# Epoch 81
# Quantile : 142655.1944, Meilleur score : 130208.289394
# Epoch 82
# Quantile : 143520.378065, Meilleur score : 130776.690106
# Epoch 83
# Quantile : 142863.431828, Meilleur score : 129966.1452
# Epoch 84
# Quantile : 141606.341271, Meilleur score : 133427.987871
# Epoch 85
# Quantile : 141143.949925, Meilleur score : 116712.265874
# Epoch 86
# Quantile : 141818.135987, Meilleur score : 127469.477823
# Epoch 87
# Quantile : 141290.265856, Meilleur score : 126329.044651
# Epoch 88
# Quantile : 141395.494458, Meilleur score : 128450.624368
# Epoch 89
# Quantile : 140851.099505, Meilleur score : 127329.151425
# Epoch 90
# Quantile : 139936.912831, Meilleur score : 126413.693012
# Epoch 91
# Quantile : 136851.02558, Meilleur score : 125681.230139
# Epoch 92
# Quantile : 140458.154819, Meilleur score : 128675.502998
# Epoch 93
# Quantile : 139007.19873, Meilleur score : 122071.051069
# Epoch 94
# Quantile : 141224.770723, Meilleur score : 126453.751306
# Epoch 95
# Quantile : 141051.588881, Meilleur score : 128451.078265
# Epoch 96
# Quantile : 139148.221945, Meilleur score : 122909.470748
# Epoch 97
# Quantile : 137395.445898, Meilleur score : 122644.269709
# Epoch 98
# Quantile : 138300.406722, Meilleur score : 119927.756026
# Epoch 99
# Quantile : 138492.084318, Meilleur score : 122356.100074
# Epoch 100
# Quantile : 139960.100912, Meilleur score : 129949.171187
# Epoch 101
# Quantile : 137539.354574, Meilleur score : 126506.284485
# Epoch 102
# Quantile : 139297.026373, Meilleur score : 126099.482427
# Epoch 103
# Quantile : 137427.978676, Meilleur score : 119802.552873
# Epoch 104
# Quantile : 137418.298808, Meilleur score : 126482.294656
# Epoch 105
# Quantile : 138269.521113, Meilleur score : 126671.756899
# Epoch 106

# %%
print(tsp_Bayes.solution)
# Out:
# [ 0 11  2 13  3  6  7  9 14  5  8  4 12  1 10  0]

# %% [markdown]
# ### Affichage sur une carte

# %%
import folium

# %%
def plot_my_world_tour(tsp1,df,tsp2=None):
    
    permut1 = tsp1.solution
    locations1 = df.iloc[permut1,:][['lat', 'lng']]
    names1 = df.iloc[permut1,:]['city_ascii']
    locationlist1 = locations1.values.tolist()

    #centre la map sur Paris
    map_osm = folium.Map(location=[48.82, 2.26],zoom_start=1.5)

    #affiche les villesp points pas points
    for point in range(0, len(locationlist1)):
        folium.Marker(locationlist1[point], popup=names1.iloc[point]).add_to(map_osm)
        
    #relie les villes entre elles selon le tour optimal
    folium.PolyLine(locationlist1).add_to(map_osm)
    
    if tsp2:

        permut2 = tsp2.solution
        locations2 = df.iloc[permut2,:][['lat', 'lng']]
        names2 = df.iloc[permut2,:]['city_ascii']
        locationlist2 = locations2.values.tolist()
        
        #affiche les villesp points pas points
        for point in range(0, len(locationlist2)):
            folium.Marker(locationlist2[point], popup=names2.iloc[point]).add_to(map_osm)

        #relie les villes entre elles selon le tour optimal
        folium.PolyLine(locationlist2, color="red").add_to(map_osm)

    

    return map_osm

# %%
plot_my_world_tour(tsp_Smooth,df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Autres examples

# %% [markdown]
# ## GR17

# %% [markdown]
# GR17 is a set of 17 cities, from TSPLIB. The minimal tour has length 2085.
#
# Meilleur score obtenu par l'algo : 2096

# %%
c = np.loadtxt('https://people.sc.fsu.edu/~jburkardt/datasets/tsp/gr17_d.txt')

# %%
c.shape
# Out:
# (17, 17)

# %%
# %%time
#TSP = CE_solution(c,k=5,perc=1)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs

# %% [markdown]
# ## ATT48

# %% [markdown]
# ATT48 is a set of 48 cities (US state capitals) from TSPLIB. The minimal tour has length 10628.
#
# Meilleur score obtenu par l'algo :
#
# Sur ce dataset on est tres loin de la solution optimale !!!!!! (pourquoi? )

# %%
c = np.loadtxt('https://people.sc.fsu.edu/~jburkardt/datasets/tsp/att48_d.txt')
c.shape
# Out:
# (48, 48)

# %%
# %%time
#TSP = CE_solution(c,k=5,perc=1)
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs

# %% [markdown]
# ## ft53

# %% [markdown]
# Dataset de l'article

# %%
def read_atsp(url):
     
    ds = np.DataSource()
    input_f = ds.open(url)
    num_lines_skip = 6
    lst = []
     
    for i, line in enumerate(input_f):
    
        if (i <= num_lines_skip) or ('EOF' in line):
            continue

        else:
            lst.append(line)
  
    lst = ''.join(lst).replace('\n', '').split()
     
    return np.array(lst, dtype=int).reshape(53, 53)

# %%
c = read_atsp('http://elib.zib.de/pub/mp-testdata/tsp/tsplib/atsp/ft53.atsp')

# %%
c.shape

# %%
for i in range(c.shape[0]):
    c[i,i] = 0

# %%
c

# %%
def CE_solution(c,k=10,alpha=0.7,perc=1,stop=5):
    TSP = TSPCrossEntropy(c,k=k,alpha=alpha,perc=perc,stop=stop)
    TSP.CE_fit()
    return TSP

# %%
# %%time
#TSP = CE_solution(c)
